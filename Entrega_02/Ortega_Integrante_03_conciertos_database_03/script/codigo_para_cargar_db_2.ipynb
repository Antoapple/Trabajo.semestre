# %%
import pandas as pd
datos=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Conciertos_database_limpia.csv", delimiter=';')
datos
# Out:
#         ID                Concierto            Recinto  \
# 0      1.0  X The Future is Unknown        Club Hípico
# 1      1.0  X The Future is Unknown        Club Hípico
# 2      1.0  X The Future is Unknown        Club Hípico
# 3      1.0  X The Future is Unknown        Club Hípico
# 4      1.0  X The Future is Unknown        Club Hípico
# ..     ...                      ...                ...
# 225  203.0      El grito de la raza  Teatro Caupolicán
# 226  204.0                     Gepe  Teatro Caupolicán
# 227  205.0        Vida En Rosa Tour  Teatro Caupolicán
# 228    NaN                      NaN                NaN
# 229    NaN                      NaN                NaN
#
#     Productora/organizadora   Tiquetera        Fecha Numero_asistentes  \
# 0            Street Machine  PuntoTicket  28-09-2024         Sin datos
# 1            Street Machine  PuntoTicket  28-09-2024         Sin datos
# 2            Street Machine  PuntoTicket  28-09-2024         Sin datos
# ...
