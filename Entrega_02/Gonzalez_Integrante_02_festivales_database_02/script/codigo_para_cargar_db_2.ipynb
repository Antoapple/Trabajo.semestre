# %%
import pandas as pd
datos=pd.read_csv("/content/drive/MyDrive/Festivales_database_limpia.csv", delimiter=';')
datos
# Out:
#      ID                 Festival                Recinto  \
# 0     1  Crush Power Music 2024   Parque Padre Hurtado
# 1     1  Crush Power Music 2024   Parque Padre Hurtado
# 2     1  Crush Power Music 2024   Parque Padre Hurtado
# 3     1  Crush Power Music 2024   Parque Padre Hurtado
# 4     1  Crush Power Music 2024   Parque Padre Hurtado
# ..   ..                      ...                    ...
# 650  35      Santiago Rocks 2024       Hipodromo Chile
# 651  35      Santiago Rocks 2024       Hipodromo Chile
# 652  35      Santiago Rocks 2024       Hipodromo Chile
# 653  35      Santiago Rocks 2024       Hipodromo Chile
# 654  35      Santiago Rocks 2024       Hipodromo Chile
#
#        Productora/ organizadora    Tiquetera        Fecha Numero_asistentes  \
# 0    Bizarro Live Entertainment  PuntoTicket   20-01-2024    Mas de 18 mil
# 1    Bizarro Live Entertainment  PuntoTicket   20-01-2024    Mas de 18 mil
# ...
