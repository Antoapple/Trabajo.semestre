# %%
import pandas as pd
datos=pd.read_csv("/content/Recintos_database_limpia (3).csv", delimiter=";")
datos
# Out:
#                               NOMBRE RECINTO  \
# 0                                Claro Arena
# 1                                Club Hípico
# 2                             Espacio Riesco
# 3         Estadio Bicentenario de La Florida
# 4          Estadio Monumental David Arellano
# 5   Estadio Nacional Julio Martínez Prádanos
# 6                        Estadio Santa Laura
# 7                            Hipódromo Chile
# 8                             Movistar Arena
# 9           Parque Bicentenario de Cerrillos
# 10         Parque Deportivo Estadio Nacional
# 11                     Parque Padre Hurtado
# 12                         Teatro Caupolicán
#
#                                 DIRECCIÓN          COMUNA  \
# 0                    Av. Las Flores 13000      Las Condes
# 1                Av. Blanco Encalada 2540        Santiago
# 2                       Av. El Salto 5000      Huechuraba
# 3                   Enrique Olivares 1003      La Florida
# ...
